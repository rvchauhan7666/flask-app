# %%
import joblib
model = joblib.load("model.pkl")
print(model.n_features_in_)  # This will show the expected number of features
# Out:
# 17
# c:\Users\admin\AppData\Local\Programs\Python\Python313\Lib\pickle.py:1760: UserWarning: [20:09:22] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\data\../common/error_msg.h:82: If you are loading a serialized model (like pickle in Python, RDS in R) or
# configuration generated by an older version of XGBoost, please export the model by calling
# `Booster.save_model` from that version first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/stable/tutorials/saving_model.html
#
# for more details about differences between saving model and serializing.
#
#   setstate(state)

# %%
import joblib

# Load the trained model
model = joblib.load("model.pkl")

# Print the expected number of features
print(f"Model expects {model.n_features_in_} features")
# Out:
# Model expects 17 features

# %%
print("Features used for training:", list(X.columns))
print("Total features:", len(X.columns))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print("Features used for training:", list(X.columns))
#       2 print("Total features:", len(X.columns))
#
# NameError: name 'X' is not defined
